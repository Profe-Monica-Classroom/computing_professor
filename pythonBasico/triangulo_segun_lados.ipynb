# %% [markdown]
# **PROGRAMA DE PRACTICA BASICA DE PYTHON**
#
# Esto es un programa para los estudiantes de Computacion 1 de la Unexpo, de la carrera de Ingenieria Mecatronica, del tercer semestre. Quienes estan aprendiendo a programar en python.
#
# **1.** Encabezado del codigo

# %%
"""
### Nombre del Programa: Triangulo y Area                      
//# Autor: Mónica Tahan                                                 
//# Versión: 1.0                                                        
//# Descripción: programa para calcular el área de un triangulo segun sus lados                     
###
"""

# %% [markdown]
# **2.** Variables (Inicializacion)

# %%
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# INICIALIZACION DE VARIABLES
#######################################################################
# ESTO ES UN COMENTARIO DE 1 LINEA

lado1=0.0
lado2=0.0
lado3=0.0
base=0.0
altura=0.0
tipo_medida='A'
tipo_triangulo=''
nombre_medida=''

# %% [markdown]
# **3.** Mensajes de inicio y bienvenida

# %%
print("Bienvenidos al programa de calculo del area del triangulo,") 
print("para continuar presione cualquier tecla")
input()
# Out:
# Bienvenidos al programa de calculo del area del triangulo,
# para continuar presione cualquier tecla
# ''

# %% [markdown]
# **4.** Parametrizacion del Menu y lectura de opcion que seleccione el usuario

# %%
while tipo_medida=='A' or tipo_medida=='B' or tipo_medida=='C':
    # SOLICITUD DEL TIPO DE MEDIDA EN EL MENU
    print("Por favor indique el tipo de medida de su triangulo:")
    print("A. Centimetros (cms)")
    print("B. Metros (mts)")
    print("C. Milimetros (mms)")
    input(tipo_medida)
    # VALIDACION DEL TIPO DE MEDIDA
    if tipo_medida=='A' or tipo_medida=='a':
        nombre_medida="cms"
    if tipo_medida=='B' or tipo_medida=='b':
        nombre_medida="mts"
    if tipo_medida=='C' or tipo_medida=='c':
        nombre_medida="mms"
    # SOLICITUD DE LOS VALORES DEL TRIANGULO
    print("Por favor indicar el valor de la base")
    base = int(input())
    print(base)
    print("Por favor indicar el valor de la altura")
    altura = int(input())
    print(altura)
    print("Por favor indicar el valor del lado 1")
    lado1 = int(input())
    print(lado1)
    print("Por favor indicar el valor del lado 2")
    lado2 = int(input())
    print(lado2)
    print("Por favor indicar el valor del lado 3")
    lado3 = int(input())
    print(lado3)

    # CALCULO DEL AREA
    area = (base*altura)/2
    
    if lado1==lado3 and lado2==lado3:
        tipo_triangulo="Equilatero"
    elif lado1 == lado2  or lado1==lado3:
        tipo_triangulo="Isosceles"
    else:
        tipo_triangulo="Escaleno"

    #MOSTRAR EL RESULTADO    
    
    print("El area del triangulo es: ", area, " ", nombre_medida, "y es del tipo: ", tipo_triangulo)
    print("Gracias por usar este programa")
    input()
# Out:
# Por favor indique el tipo de medida de su triangulo:
# A. Centimetros (cms)
# B. Metros (mts)
# C. Milimetros (mms)
# Por favor indicar el valor de la base
# 5
# Por favor indicar el valor de la altura
# 7
# Por favor indicar el valor del lado 1
# 4
# Por favor indicar el valor del lado 2
# 4
# Por favor indicar el valor del lado 3
# 4
# El area del triangulo es:  17.5   cms y es del tipo:  Equilatero
# Gracias por usar este programa

# %%
    # SOLICITUD DE LOS VALORES DEL TRIANGULO
    print("Por favor indicar el valor de la base")
    base = input()
    base = int(base)
    print(base)
    #base=int(base)
    print("Por favor indicar el valor de la altura")
    input(altura)
    print("Por favor indicar el valor del lado 1")
    input(lado1)
    print("Por favor indicar el valor del lado 2")
    input(lado2)
    print("Por favor indicar el valor del lado 3")
    input(lado3)

    # CALCULO DEL AREA
    area=(base*altura)/2
    
    if lado1==lado3 and lado2==lado3:
        tipo_triangulo="Equilatero"
    elif lado1 == lado2  or lado1==lado3:
        tipo_triangulo="Isosceles"
    else:
        tipo_triangulo="Escaleno"

    #MOSTRAR EL RESULTADO    
    
    print("El area del triangulo es: ", area, " ", nombre_medida, "y es del tipo: ", tipo_triangulo)
    print("Gracias por usar este programa")
    input()
